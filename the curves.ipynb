# %%
thread1 = [1.135, 0.95, 0.987, 1.002]
thread1
# Out:
# [1.135, 0.95, 0.987, 1.002]

# %%
thread2 = [1.851, 1.567, 1.488, 1.36]
thread2
# Out:
# [1.851, 1.567, 1.488, 1.36]

# %%
thread3 = [2.317, 2.174, 1.737, 1.6357]
thread3
# Out:
# [2.317, 2.174, 1.737, 1.6357]

# %%
thread4 = [2.664, 2.344, 1.875, 1.721]
thread4
# Out:
# [2.664, 2.344, 1.875, 1.721]

# %%
thread5 = [2.77, 2.863, 1.915, 1.878]
thread5
# Out:
# [2.77, 2.863, 1.915, 1.878]

# %%
thread6 = [2.84, 3.298, 1.986, 1.983]
thread6
# Out:
# [2.84, 3.298, 1.986, 1.983]

# %%
thread7 = [3.002, 3.398, 2.045, 2.005]
thread7
# Out:
# [3.002, 3.398, 2.045, 2.005]

# %%
thread8 = [3.674, 3.441, 2.071, 2.015]
thread8
# Out:
# [3.674, 3.441, 2.071, 2.015]

# %%
thread = [thread1, thread2, thread3, thread4, thread5, thread6, thread7, thread8]
thread
# Out:
# [[1.135, 0.95, 0.987, 1.002],
#  [1.851, 1.567, 1.488, 1.36],
#  [2.317, 2.174, 1.737, 1.6357],
#  [2.664, 2.344, 1.875, 1.721],
#  [2.77, 2.863, 1.915, 1.878],
#  [2.84, 3.298, 1.986, 1.983],
#  [3.002, 3.398, 2.045, 2.005],
#  [3.674, 3.441, 2.071, 2.015]]

# %%
t3000 = [thread1[0], thread2[0], thread3[0], thread4[0], thread5[0], thread6[0], thread7[0], thread8[0]]
t3000
# Out:
# [1.135, 1.851, 2.317, 2.664, 2.77, 2.84, 3.002, 3.674]

# %%
t4000 = [thread1[1], thread2[1], thread3[1], thread4[1], thread5[1], thread6[1], thread7[1], thread8[1]]
t4000
# Out:
# [0.95, 1.567, 2.174, 2.344, 2.863, 3.298, 3.398, 3.441]

# %%
t5000 = [thread1[2], thread2[2], thread3[2], thread4[2], thread5[2], thread6[2], thread7[2], thread8[2]]
t5000
# Out:
# [0.987, 1.488, 1.737, 1.875, 1.915, 1.986, 2.045, 2.071]

# %%
t6000 = [thread1[3], thread2[3], thread3[3], thread4[3], thread5[3], thread6[3], thread7[3], thread8[3]]
t6000
# Out:
# [1.002, 1.36, 1.6357, 1.721, 1.878, 1.983, 2.005, 2.015]

# %%
th = [t3000, t4000, t5000, t6000]
th
# Out:
# [[1.135, 1.851, 2.317, 2.664, 2.77, 2.84, 3.002, 3.674],
#  [0.95, 1.567, 2.174, 2.344, 2.863, 3.298, 3.398, 3.441],
#  [0.987, 1.488, 1.737, 1.875, 1.915, 1.986, 2.045, 2.071],
#  [1.002, 1.36, 1.6357, 1.721, 1.878, 1.983, 2.005, 2.015]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot([1,2,3,4,5,6,7,8], [1.135, 1.851, 2.317, 2.664, 2.77, 2.84, 3.002, 3.674],label='3000')
plt.plot([1,2,3,4,5,6,7,8], [0.95, 1.567, 2.174, 2.344, 2.863, 3.298, 3.398, 3.441],label='4000')
plt.plot([1,2,3,4,5,6,7,8], [0.987, 1.488, 1.737, 1.875, 1.915, 1.986, 2.045, 2.071],label='5000')
plt.plot([1,2,3,4,5,6,7,8], [1.002, 1.36, 1.6357, 1.721, 1.878, 1.983, 2.005, 2.015],label='6000')
plt.title('Speedup en fonction de Nombre de Threads')
plt.xlabel('Nombre de Threads')
plt.ylabel('Speedup ')
plt.ylim(0.5,4)
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot([3000,4000,5000,6000], [1.135, 0.95, 0.987, 1.002],label='Thread 1')
plt.plot([3000,4000,5000,6000], [1.851, 1.567, 1.488, 1.36],label='Thread 2')
plt.plot([3000,4000,5000,6000], [2.317, 2.174, 1.737, 1.6357],label='Thread 3')
plt.plot([3000,4000,5000,6000], [2.664, 2.344, 1.875, 1.721],label='Thread 4')
plt.plot([3000,4000,5000,6000], [2.77, 2.863, 1.915, 1.878],label='Thread 5')
plt.plot([3000,4000,5000,6000], [2.84, 3.298, 1.986, 1.983],label='Thread 6')
plt.plot([3000,4000,5000,6000], [3.002, 3.398, 2.045, 2.005],label='Thread 7')
plt.plot([3000,4000,5000,6000], [3.674, 3.441, 2.071, 2.015],label='Thread 8')
plt.title('Speedup en fonction de Taille du problème')
plt.xlabel('Taille du problème')
plt.ylabel('Speedup ')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot([3000,4000,5000,6000], [2.317, 2.174, 1.737, 1.6357],label='3-voisins')
plt.plot([3000,4000,5000,6000], [2.77, 2.863, 1.915, 1.878],label='5-voisins')
plt.plot([3000,4000,5000,6000], [3.674, 3.441, 2.071, 2.015],label='8-voisins')
plt.title('Speedup en fonction de Taille du problème')
plt.xlabel('Taille du problème')
plt.ylabel('Speedup ')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot([3000,4000,5000,6000], [6.594, 10.117, 19.465, 26.511],label='Thread 1')
plt.plot([3000,4000,5000,6000], [4.044, 6.137, 12.916, 19.534],label='Thread 2')
plt.plot([3000,4000,5000,6000], [3.231, 4.424, 11.068, 16.245],label='Thread 3')
plt.plot([3000,4000,5000,6000], [2.81, 4.102, 10.254, 15.433],label='Thread 4')
plt.plot([3000,4000,5000,6000], [2.703, 3.359, 10.037, 14.142],label='Thread 5')
plt.plot([3000,4000,5000,6000], [2.631, 2.916, 9.680, 13.396],label='Thread 6')
plt.plot([3000,4000,5000,6000], [2.494, 2.830, 9.398, 13.250],label='Thread 7')
plt.plot([3000,4000,5000,6000], [2.038, 2.795, 9.283, 13.186],label='Thread 8')
plt.title('Taille du problème en fonction de Temps')
plt.xlabel('Taille du problème')
plt.ylabel('Temps (s)')
plt.legend()
